# %%
from ift6758.data.question_4 import *
from ift6758.data.question_5 import *

tdf = Tidyer()
df = tdf.game_event_to_panda_df(2017)['regular']

# %%
print(df[df[EVENT_TYPE]=="Goal"][COORD_X].mean())
print(df[df[EVENT_TYPE]=="Goal"][COORD_Y].mean())
# Out:
# 0.5035128805620609
# 0.06336195680457976

# %%
print(df[df[EVENT_TYPE]=="Shot"][COORD_X].mean())
print(df[df[EVENT_TYPE]=="Shot"][COORD_Y].mean())
# Out:
# 0.3015004246484854
# -0.3188368675770771

# %%
histo_shot(2017)
